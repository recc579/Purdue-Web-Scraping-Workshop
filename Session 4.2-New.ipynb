# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import urllib.request
import time
import random
import re

# %%
url = "https://www.getcompanyinfo.com/industry/information-technology-services/"
html = urllib.request.urlopen(url).read().decode('utf-8')
soup = bs(html)

# %%
Company = []
Link = []
Type = []
Industry = []
Founded = []
Country = []
City = []
State = []
Phone = []
Email = []
Website = []
Employees = []


Companies = [x.get_text() for x in soup.find_all(title = "Company Name")]
Links = [x['href'] for x in soup.find_all(title = "Company Name")]
url_base = "https://www.getcompanyinfo.com"


for n in range(len(Companies)):
    html2 = urllib.request.urlopen(url_base+Links[n]).read().decode('utf-8')
    soup2 = bs(html2)
    Company.append(Companies[n])
    Link.append(Links[n])
    Type.append(soup2.find("label",text="Company Type:").find_next_sibling().get_text())
    Industry.append(soup2.find("label",text="Industry:").find_next_sibling().get_text())
    Founded.append(soup2.find("label",text="Founded:").find_next_sibling().get_text())
    Country.append(soup2.find("label",text="Country:").find_next_sibling().get_text())
    cityState = soup2.find("label",text="Headquarter:").find_next_sibling().get_text()
    split = cityState.split(",")
    City.append(split[0])
    State.append(split[1].strip())
    Phone.append(soup2.find("label",text="Phone:").find_next_sibling().get_text())
    Email.append(soup2.find("label",text="Email:").find_next_sibling().get_text())
    Website.append(soup2.find("label",text="Website:").find_next_sibling().get_text())
    Employees.append(soup2.find("h4",text="Employees").find_next_sibling().get_text())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ee28ab194eb0> in <module>
#      31     City.append(split[0])
#      32     State.append(split[1].strip())
# ---> 33     Phone.append(soup2.find("label",text="Phone:").find_next_sibling().get_text())
#      34     Email.append(soup2.find("label",text="Email:").find_next_sibling().get_text())
#      35     Website.append(soup2.find("label",text="Website:").find_next_sibling().get_text())
#
# AttributeError: 'NoneType' object has no attribute 'find_next_sibling'

# %%
Companies[n]
# Out:
# 'Hewlett Packard Enterprise'

# %%
Company = []
Link = []
Type = []
Industry = []
Founded = []
Country = []
City = []
State = []
Phone = []
Email = []
Website = []
Employees = []

Companies = [x.get_text() for x in soup.find_all(title = "Company Name")]
Links = [x['href'] for x in soup.find_all(title = "Company Name")]
url_base = "https://www.getcompanyinfo.com"


for n in range(len(Companies)):
    html2 = urllib.request.urlopen(url_base+Links[n]).read().decode('utf-8')
    soup2 = bs(html2)
    Company.append(Companies[n])
    Link.append(Links[n])
    try:
        Type.append(soup2.find("label",text="Company Type:").find_next_sibling().get_text())
    except:
        Type.append(None)
    try:
        Industry.append(soup2.find("label",text="Industry:").find_next_sibling().get_text())
    except:
        Industry.append(None)
    try:
        Founded.append(soup2.find("label",text="Founded:").find_next_sibling().get_text())
    except:
        Founded.append(None)
    try:
        Country.append(soup2.find("label",text="Country:").find_next_sibling().get_text())
    except:
        Country.append(None)
    try:
        cityState = soup2.find("label",text="Headquarter:").find_next_sibling().get_text()
        split = cityState.split(",")
        City.append(split[0])
        State.append(split[1])
    except:
        City.append(None)
        State.append(None)
    try:
        Phone.append(soup2.find("label",text="Phone:").find_next_sibling().get_text())
    except:
        Phone.append(None)
    try:
        Email.append(soup2.find("label",text="Email:").find_next_sibling().get_text())
    except:
        Email.append(None)
    try:
        Website.append(soup2.find("label",text="Website:").find_next_sibling().get_text())
    except:
        Website.append(None)
    try:
        Employees.append(soup2.find("h4",text="Employees").find_next_sibling().get_text())
    except:
        Employees.append(None)

# %%
pd.DataFrame({"Company":Company,
             "Link":Link,
             "Type":Type,
             "Industry":Industry,
             "Founded":Founded,
             "Country":Country,
             "City":City,
             "State":State,
             "Phone":Phone,
             "Email":Email,
             "Website":Website,
             "Employees":Employees})
# Out:
#                        Company                                  Link     Type  \
# 0                    Accenture                   /company/accenture/   Public
# 1    Tata Consultancy Services   /company/tata-consultancy-services/   Public
# 2                Ernst & Young                 /company/ernst-young/  Private
# 3                    Cognizant                   /company/cognizant/   Public
# 4                      Infosys                     /company/infosys/   Public
# 5   Hewlett Packard Enterprise  /company/hewlett-packard-enterprise/   Public
# 6                    Capgemini                   /company/capgemini/   Public
# 7                        Wipro                       /company/wipro/   Public
# 8                       Oracle                      /company/oracle/   Public
# 9             HCL Technologies            /company/hcl-technologies/   Public
# 10      Verizon Communications      /company/verizon-communications/   Public
# 11                        Dell                        /company/dell/  Private
#
#                              Industry Founded         Country            City  \
# 0   Information Technology & Services    1989         Ireland        Dublin 2
# 1   Information Technology & Services    1968           India          Mumbai
# 2   Information Technology & Services    1989  United Kingdom          London
# 3   Information Technology & Services    1994   United States         Teaneck
# 4   Information Technology & Services    1981           India       Bangalore
# 5   Information Technology & Services    1939   United States        San Jose
# 6   Information Technology & Services    1967          France           Paris
# 7   Information Technology & Services    1945           India       Bangalore
# 8   Information Technology & Services    1977   United States  Redwood Shores
# 9   Information Technology & Services    1976           India           Noida
# 10  Information Technology & Services    1983   United States        New York
# 11  Information Technology & Services    1984   United States      Round Rock
#
#               State         Phone                      Email  \
# 0     County Dublin   35316462000    careersph@accenture.com
# 1       Maharashtra  912267789999         contact.us@tcs.com
# 2    Greater London  442079512000           sholt2@uk.ey.com
# 3        New Jersey   12018010233      inquiry@cognizant.com
# 4         Karnataka  918028520261      investors@infosys.com
# 5        California          None                       None
# 6             Paris   33147545000      info.me@capgemini.com
# 7         Karnataka  918028440011             info@wipro.com
# 8        California   18006330738  oracle-acct_ww@oracle.com
# 9     Uttar Pradesh          None                       None
# 10         New York          None                       None
# 11            Texas          None                       None
#
#                       Website    Employees
# 0    http://www.accenture.com  Above 10000
# 1        https://www.tcs.com/  Above 10000
# 2               http://ey.com  Above 10000
# 3   https://www.cognizant.com  Above 10000
# 4    https://www.infosys.com/  Above 10000
# 5         https://www.hpe.com  Above 10000
# 6   https://www.capgemini.com  Above 10000
# 7        http://www.wipro.com  Above 10000
# 8     https://www.oracle.com/  Above 10000
# 9    https://www.hcltech.com/  Above 10000
# 10   https://www.verizon.com/  Above 10000
# 11        http://www.dell.com  Above 10000

# %% [markdown]
# Now we need to tackle the next page.

# %%
# Code for next page
soup.find_all("ul", class_="pagination")
soup.find("ul",class_="pagination")
# Out:
# <ul class="pagination">
# <li class="disabled"><a href="#">«</a></li>
# <li class="active"><a href="?page=1">1 <span class="sr-only">(current)</span></a>
# </li>
# <li><a href="?page=2">2</a></li>
# <li><a href="?page=3">3</a></li>
# <li><a href="?page=4">4</a></li>
# <li><a href="?page=5">5</a></li>
# <li><a href="?page=6">6</a></li>
# <li><a href="?page=2">»</a></li>
# </ul>

# %%
soup.find("ul",class_="pagination").find_all("li")[-1].findChild()["href"]
soup.find("ul",class_="pagination").find_all("a")[-1]["href"]
# Out:
# '?page=2'

# %%
Company = []
Link = []
Type = []
Industry = []
Founded = []
Country = []
City = []
State = []
Phone = []
Email = []
Website = []
Employees = []
url = "https://www.getcompanyinfo.com/industry/information-technology-services/"
Next = "?page=1"

while Next != "?page=3":#"#":
    print(Next)
    html = urllib.request.urlopen(url+Next).read().decode('utf-8')
    soup = bs(html)
    
    Companies = [x.get_text() for x in soup.find_all(title = "Company Name")]
    Links = [x['href'] for x in soup.find_all(title = "Company Name")]
    url_base = "https://www.getcompanyinfo.com"

    for n in range(len(Companies)):
        html2 = urllib.request.urlopen(url_base+Links[n]).read().decode('utf-8')
        soup2 = bs(html2)
        Company.append(Companies[n])
        Link.append(Links[n])
        try:
            Type.append(soup2.find("label",text="Company Type:").find_next_sibling().get_text())
        except:
            Type.append(None)
        try:
            Industry.append(soup2.find("label",text="Industry:").find_next_sibling().get_text())
        except:
            Industry.append(None)
        try:
            Founded.append(soup2.find("label",text="Founded:").find_next_sibling().get_text())
        except:
            Founded.append(None)
        try:
            Country.append(soup2.find("label",text="Country:").find_next_sibling().get_text())
        except:
            Country.append(None)
        try:
            cityState = soup2.find("label",text="Headquarter:").find_next_sibling().get_text()
            split = cityState.split(",")
            City.append(split[0])
            State.append(split[1])
        except:
            City.append(None)
            State.append(None)
        try:
            Phone.append(soup2.find("label",text="Phone:").find_next_sibling().get_text())
        except:
            Phone.append(None)
        try:
            Email.append(soup2.find("label",text="Email:").find_next_sibling().get_text())
        except:
            Email.append(None)
        try:
            Website.append(soup2.find("label",text="Website:").find_next_sibling().get_text())
        except:
            Website.append(None)
        try:
            Employees.append(soup2.find("h4",text="Employees").find_next_sibling().get_text())
        except:
            Employees.append(None)
    Next = soup.find("ul",class_="pagination").find_all("a")[-1]["href"]
    
    time.sleep(random.uniform(5,15))
print("Done!")
# Out:
# ?page=1
# ?page=2
# Done!

# %%
df=pd.DataFrame({"Company":Company,
             "Link":Link,
             "Type":Type,
             "Industry":Industry,
             "Founded":Founded,
             "Country":Country,
             "City":City,
             "State":State,
             "Phone":Phone,
             "Email":Email,
             "Website":Website,
             "Employees":Employees})

# %%
df
# Out:
#                        Company                                  Link     Type  \
# 0                    Accenture                   /company/accenture/   Public
# 1    Tata Consultancy Services   /company/tata-consultancy-services/   Public
# 2                Ernst & Young                 /company/ernst-young/  Private
# 3                    Cognizant                   /company/cognizant/   Public
# 4                      Infosys                     /company/infosys/   Public
# 5   Hewlett Packard Enterprise  /company/hewlett-packard-enterprise/   Public
# 6                    Capgemini                   /company/capgemini/   Public
# 7                        Wipro                       /company/wipro/   Public
# 8                       Oracle                      /company/oracle/   Public
# 9             HCL Technologies            /company/hcl-technologies/   Public
# 10      Verizon Communications      /company/verizon-communications/   Public
# 11                        Dell                        /company/dell/  Private
# 12                     Genpact                     /company/genpact/   Public
# 13              DXC Technology              /company/dxc-technology/   Public
# 14                          HP                          /company/hp/   Public
# 15                    Dell EMC                    /company/dell-emc/  Private
# 16                 CenturyLink                 /company/centurylink/   Public
# 17                       Xerox                       /company/xerox/   Public
# 18                         CGI                         /company/cgi/   Public
# 19             Thomson Reuters             /company/thomson-reuters/   Public
# 20                EPAM Systems                /company/epam-systems/   Public
# 21                         NCR                         /company/ncr/   Public
# 22                Sopra Steria                /company/sopra-steria/   Public
# 23                        SAIC                        /company/saic/   Public
#
#                              Industry Founded         Country            City  \
